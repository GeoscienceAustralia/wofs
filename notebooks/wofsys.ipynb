# %% [markdown]
# # WOfS-v2 System demo

# %% [markdown]
# ##  Setting up environment: python modules etc

# %%
##  Setting up environment: python modules etc

# make my current source code python modules available in this notebook
import sys

paths=sys.path
#paths.append('/g/data1/u46/fxz547/Githubz/agdc-v2')
paths.insert(0,'/g/data1/u46/fxz547/Githubz/agdc-v2')  #prepend a path

paths.append('/g/data1/u46/fxz547/Githubz/wofs')

# %%
from IPython.display import display
from pprint import pprint
from __future__ import print_function

import os
import glob
import numpy as np
import math
from pathlib import Path

from netCDF4 import Dataset, num2date, date2num
from collections import defaultdict
import xarray as xr
import xarray.ufuncs

import datacube
from datacube.api import GridWorkflow
from datacube.storage import  masking
from datacube.storage.storage import write_dataset_to_netcdf
#from datacube.index import index_connect
#from datacube.config import LocalConfig
#from datacube.api._conversion import to_datetime
#new updated version: from datacube.api import make_mask, describe_flags

from wofs.workflow.agdc_dao import AgdcDao
import wofs.workflow.make_water_tiles as mkwater

# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10 # increase plot size a bit...
rcParams['axes.formatter.useoffset'] = False  # disable scalar formatter / offset in axes labels

# %% [markdown]
# ## Classify NBAR tiles

# %%
cellindex=(15,-40)
day1='1990-01-01'
day2='1990-12-31'
qdict = {'platform': ['LANDSAT_5'], 'time': (day1, day2)}
print (qdict)

dcdao = AgdcDao()

nbar_pq_data = dcdao.get_multi_nbarpq_tiledata(cellindex, qdict, maxtiles=50)  # maxtiles=100 for a year
#To be more specific, able to retrieve using eg, ((15, -40), numpy.datetime64('1992-09-16T09:12:23.500000000+1000'))

# todo: get DSM data for this cell
dsm_data = dcdao.get_dsm_data(cellindex, {})

print("Number of (nbar,pqa) tile-pairs:", len(nbar_pq_data))

# Now ready to apply classification algorithm to the data tiles retrieved.

icounter = 0

for (celltime_key, nbar_tile, pq_tile) in nbar_pq_data:
    print (celltime_key)
    cellindex_tup = celltime_key[0]
    acq_dt = celltime_key[1]
    dtstamp = str(acq_dt)[:19].replace(':', '-')
    platform = 'LS5'  # can get from the nbar tile data

    water_classified_img = mkwater.produce_water_tile(nbar_tile, pq_tile, dsm_data[cellindex_tup])

    path2_waterfile = mkwater.define_water_fname(platform, cellindex_tup, dtstamp, nbar_tile)

    write_dataset_to_netcdf(water_classified_img,
                            global_attributes={},
                            variable_params={'waterextent': {'zlib': True}},
                            filename=Path(path2_waterfile))

    icounter += 1
# Out:
# {'platform': ['LANDSAT_5'], 'time': ('1990-01-01', '1990-12-31')}
# Number of (nbar,pqa) tile-pairs: 24
# ((15, -40), numpy.datetime64('1990-03-03T10:11:16.000000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6485041))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 248547, 2183040, 101733, 252536, 6485041, 6729103)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=11.3608840625, variance=691.28008558593353, skewness=2.394811289497464, kurtosis=5.235928558904158)
# ('DateTime of satellite observation: ', '1990-03-03T10-11-16')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-16.nc
# ((15, -40), numpy.datetime64('1990-03-03T10:11:39.000000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7126900))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 25995, 806485, 322976, 80724, 7126900, 7636920)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=4.5353737499999998, variance=233.64551580065574, skewness=3.922938827471967, kurtosis=15.675956968896212)
# ('DateTime of satellite observation: ', '1990-03-03T10-11-39')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-39.nc
# ((15, -40), numpy.datetime64('1990-04-04T09:10:42.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6556835))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 18719, 4391563, 163824, 94520, 6556835, 4774539)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=18.465269187499999, variance=813.3604368556895, skewness=1.0082544770759998, kurtosis=-0.8505498301692334)
# ('DateTime of satellite observation: ', '1990-04-04T09-10-42')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-04-04T09-10-42.nc
# ((15, -40), numpy.datetime64('1990-05-06T09:10:28.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6163928))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 86405, 5514889, 33096, 252188, 6163928, 3949494)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=23.233757000000001, variance=963.04933635552106, skewness=0.7388657786921387, kurtosis=-1.0895912960779688)
# ('DateTime of satellite observation: ', '1990-05-06T09-10-28')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-05-06T09-10-28.nc
# ((15, -40), numpy.datetime64('1990-06-07T09:10:29.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6265317))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 214004, 2691968, 341671, 245345, 6265317, 6241695)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=13.5854964375, variance=746.03809973655723, skewness=1.9601497301617212, kurtosis=3.1173704186862983)
# ('DateTime of satellite observation: ', '1990-06-07T09-10-29')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-06-07T09-10-29.nc
# ((15, -40), numpy.datetime64('1990-07-09T09:10:50.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6966700))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 486983, 3961865, 562980, 67192, 6966700, 3954280)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=21.313101750000001, variance=1095.1427309905689, skewness=1.3848873871596354, kurtosis=1.078450847993322)
# ('DateTime of satellite observation: ', '1990-07-09T09-10-50')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-09T09-10-50.nc
# ((15, -40), numpy.datetime64('1990-07-25T09:10:22.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6332946))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 314667, 822478, 834835, 248649, 6332946, 7446425)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=7.90380825, variance=524.19063528414608, skewness=3.6251206118873234, kurtosis=13.81561590187416)
# ('DateTime of satellite observation: ', '1990-07-25T09-10-22')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-22.nc
# ((15, -40), numpy.datetime64('1990-07-25T09:10:46.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7038902))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 180626, 605416, 899600, 70442, 7038902, 7205014)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=6.1146086249999998, variance=360.59104577501569, skewness=4.17588975970955, kurtosis=19.63037443882141)
# ('DateTime of satellite observation: ', '1990-07-25T09-10-46')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-46.nc
# ((15, -40), numpy.datetime64('1990-08-10T09:10:17.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6210824))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 235206, 6554694, 180415, 250825, 6210824, 2568036)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=28.880783624999999, variance=1096.7504565028426, skewness=0.5362289642817003, kurtosis=-1.0076572488362698)
# ('DateTime of satellite observation: ', '1990-08-10T09-10-17')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-17.nc
# ((15, -40), numpy.datetime64('1990-08-10T09:10:41.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7199914))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 144038, 4747397, 249212, 70505, 7199914, 3588934)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=21.09912375, variance=934.07276823673533, skewness=1.0037401022050148, kurtosis=-0.36451763507051993)
# ('DateTime of satellite observation: ', '1990-08-10T09-10-41')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-41.nc
# ((15, -40), numpy.datetime64('1990-08-26T09:10:12.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6340969))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 360235, 11176, 8420, 251895, 6340969, 9027305)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=3.3712214375, variance=361.3747489177714, skewness=6.364844233703359, kurtosis=38.668966094500604)
# ('DateTime of satellite observation: ', '1990-08-26T09-10-12')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-12.nc
# ((15, -40), numpy.datetime64('1990-08-26T09:10:36.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7096092))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 159223, 778040, 250630, 73108, 7096092, 7642907)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=5.3398482500000002, variance=350.21073730514303, skewness=4.328529309222659, kurtosis=20.130660645533755)
# ('DateTime of satellite observation: ', '1990-08-26T09-10-36')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-36.nc
# ((15, -40), numpy.datetime64('1990-09-11T09:10:09.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6315724))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 297231, 294980, 973, 247458, 6315724, 8843634)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=3.985379, variance=364.5150702585604, skewness=5.65745700082459, kurtosis=31.87160146893423)
# ('DateTime of satellite observation: ', '1990-09-11T09-10-09')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-09.nc
# ((15, -40), numpy.datetime64('1990-09-11T09:10:33.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7032596))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 89694, 23744, 4839, 69323, 7032596, 8779804)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.270408625, variance=97.077751992885155, skewness=12.319801774823109, kurtosis=152.89913614279817)
# ('DateTime of satellite observation: ', '1990-09-11T09-10-33')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-33.nc
# ((15, -40), numpy.datetime64('1990-09-27T09:10:01.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6368414))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 338197, 296, 0, 250608, 6368414, 9042485)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=3.1361118750000001, variance=337.01500524591728, skewness=6.6482192488658605, kurtosis=42.24030716859236)
# ('DateTime of satellite observation: ', '1990-09-27T09-10-01')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-01.nc
# ((15, -40), numpy.datetime64('1990-09-27T09:10:25.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7031472))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 42748, 10, 0, 72107, 7031472, 8853663)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=0.79050437500000004, variance=43.609111308675558, skewness=19.097671733747575, kurtosis=364.8966692846174)
# ('DateTime of satellite observation: ', '1990-09-27T09-10-25')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-25.nc
# ((15, -40), numpy.datetime64('1990-10-13T09:09:54.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6230874))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 334824, 59317, 41870, 248399, 6230874, 9084716)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=3.4200794999999999, variance=349.47921543113296, skewness=6.324289173113059, kurtosis=38.69496982245884)
# ('DateTime of satellite observation: ', '1990-10-13T09-09-54')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-09-54.nc
# ((15, -40), numpy.datetime64('1990-10-13T09:10:18.000000000+1000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6974150))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 35911, 322866, 180022, 70917, 6974150, 8416134)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=2.3835449999999998, variance=125.72030271549403, skewness=6.706251799732944, kurtosis=51.30902863589994)
# ('DateTime of satellite observation: ', '1990-10-13T09-10-18')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-10-18.nc
# ((15, -40), numpy.datetime64('1990-10-29T10:09:46.000000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6124717))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 339152, 0, 0, 245924, 6124717, 9290207)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=3.1267513125000002, variance=337.95937116473152, skewness=6.639878540209044, kurtosis=42.1261671157959)
# ('DateTime of satellite observation: ', '1990-10-29T10-09-46')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-09-46.nc
# ((15, -40), numpy.datetime64('1990-10-29T10:10:10.000000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7184936))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 37805, 5, 0, 66115, 7184936, 8711139)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=0.75978287499999997, variance=38.601919645476407, skewness=20.294397188057662, kurtosis=412.63561609268095)
# ('DateTime of satellite observation: ', '1990-10-29T10-10-10')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-10-10.nc
# ((15, -40), numpy.datetime64('1990-11-14T10:09:47.500000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6065857))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 299947, 1079057, 80389, 219078, 6065857, 8255672)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=7.2830828125, variance=535.91983980376335, skewness=3.6322282583155245, kurtosis=13.304597250405529)
# ('DateTime of satellite observation: ', '1990-11-14T10-09-47')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-09-47.nc
# ((15, -40), numpy.datetime64('1990-11-14T10:10:11.500000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6923972))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 36306, 242149, 12216, 45855, 6923972, 8739502)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.7219561249999999, variance=97.42839719284953, skewness=8.57164404395071, kurtosis=81.83798879131257)
# ('DateTime of satellite observation: ', '1990-11-14T10-10-11')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-10-11.nc
# ((15, -40), numpy.datetime64('1990-12-16T10:09:43.000000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(5941522))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 321739, 1206804, 89484, 228231, 5941522, 8212220)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=7.9799699999999998, variance=580.87805397899672, skewness=3.4080526268882125, kurtosis=11.58184659801348)
# ('DateTime of satellite observation: ', '1990-12-16T10-09-43')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-09-43.nc
# ((15, -40), numpy.datetime64('1990-12-16T10:10:07.000000000+1100'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7146517))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 17521, 1100259, 156707, 51899, 7146517, 7527097)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=5.3077626875000004, variance=281.92436093595558, skewness=3.3812743902072233, kurtosis=10.45799352016185)
# ('DateTime of satellite observation: ', '1990-12-16T10-10-07')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-10-07.nc

# %%
# !ls  /g/data1/u46/fxz547/wofs2/extents/abc15_-40/*.nc
# Out:
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-16.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-39.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-04-04T09-10-42.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-05-06T09-10-28.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-06-07T09-10-29.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-09T09-10-50.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-22.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-46.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-17.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-41.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-12.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-36.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-09.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-33.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-01.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-25.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-09-54.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-10-18.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-09-46.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-10-10.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-09-47.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-10-11.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-09-43.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-10-07.nc

# %% [markdown]
# # Visualise Water Tiles

# %%
#ROOT_DIR="/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/clfs"
ROOT_DIR="/g/data/u46/users/fxz547/wofs2/extents/abc15_-40"
ncfiles=glob.glob(ROOT_DIR+'/LS5_water*_1990*.nc')

#print(sorted(ncfiles))
# Out:
# ['/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-16.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-39.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-04-04T09-10-42.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-05-06T09-10-28.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-06-07T09-10-29.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-09T09-10-50.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-22.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-46.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-17.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-41.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-12.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-36.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-09.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-33.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-01.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-25.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-09-54.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-10-18.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-09-46.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-10-10.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-09-47.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-10-11.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-09-43.nc', '/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-10-07.nc']

# %%
def showimg(path2ncfile, band4view='waterextent'):

    f = Dataset(path2ncfile, 'r')

    # The NC data variable name?
    # band4view='waterextent'
    #bandarray = f[band4view][:, :]  #for water tiles 2D array. this will load all data into RAM.
    
    # for summary, there may be a time dimension, 3D array
    # 3D 
    bandarray = f[band4view][:, :, :]  

    fig = plt.figure()

    #im = plt.imshow(bandarray[time,:,:], cmap=plt.get_cmap('viridis'), animated=True)
    #im = plt.imshow(bandarray[:,:],  vmin=0, vmax=128) 
    #3D 
    im = plt.imshow(bandarray[0, :,:], vmin=0, vmax=128 ) #, cmap=plt.get_cmap('viridis'))
    plt.colorbar(orientation='vertical', shrink=0.8, label='Water=128, No-Water=0, No-Data=1');
    
    return

# %%
# Show a list of nc files

# Define the list of nc tiles to be displayed
path2nc=[os.path.join(ROOT_DIR, ncf) for ncf in sorted(ncfiles)]
icount=0

def show_im(icount):
    path2ncimage=path2nc[ icount]  #

    print('showing image number:',icount, path2ncimage)
    showimg(path2ncimage)

    icount=icount+1
    if (icount ==len(ncfiles)):
        icount =0
        print ("Finished, resetting iount=0")
    return icount

# %%
icount=0

# %%
# execute this cell (ctr+enter) repeatedly until all done

icount = show_im(icount)
print("Next will be ", icount)
# Out:
# showing image number: 1 /g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-39.nc
# Next will be  2

# %% [markdown]
# ##  Water-Summary amd Visualization

# %%
# %pwd
# Out:
# u'/g/data1/u46/users/fxz547/Githubz/wofs/notebooks'

# %%
run /g/data1/u46/users/fxz547/Githubz/wofs/wofs/workflow/make_watersummary.py /g/data/u46/users/fxz547/wofs2/extents/abc15_-40 nc 15_-40
# Out:
# 4665723.0
# 179186648.0
# done writing /g/data/u46/users/fxz547/wofs2/summaries/water_summary_15_-40.nc

# %%
def show_water_summary(path2ncfile):
    
    f = Dataset(path2ncfile, 'r')
    
    # for summary, there may be a time dimension, 3D array
    waterdata= 'waterobs'
    cleardata='clearobs'
    
    warray = f[waterdata][:,:, :]  # this will load all data into RAM - may use up memory, spit out error
    carray = f[cleardata][:,:, :]
   


    #im = plt.imshow(bandarray[time,:,:], cmap=plt.get_cmap('viridis'), animated=True)
    # 2D-tiles im = plt.imshow(bandarray[:,:] ) 
#     im = plt.imshow(bandarray[0,:,:] ) #, cmap=plt.get_cmap('viridis'))
#     plt.colorbar(orientation='vertical', shrink=0.8, label='Water=128, No-Water=0, No-Data=1');

#     plt.figure( figsize=(16,13) )
#     plt.subplot( 1,3,1 )
    plt.imshow(warray[0,:,:] ) #, vmin=0, vmax=100)
    plt.title("Water Observations"); plt.xlabel('easting'); plt.ylabel('northing')
    plt.colorbar(orientation='vertical', shrink=0.8, label='Water Obs Counts');

    
#     plt.subplot( 1,3,2 )
#     #plt.imshow(subs_array)   # plotting the subset data directly
#     plt.imshow(carray[0,:,:], vmin=0, vmax=100, )
#     plt.title("Clear Observations"); plt.xlabel('easting'); plt.ylabel('northing')
#     plt.colorbar(orientation='vertical', shrink=0.3, label='obs counts');


#      plt.subplot( 1,3,3 )
#      plt.imshow(subs_array)   # plotting the subset data directly
#     plt.imshow(warray[0,:,:]/carray[0,:,:]) #, vmin=0, vmax=1, )
#     plt.title("Water/Clear Observations"); plt.xlabel('Easting Grid'); plt.ylabel('Northing Grid')
#     plt.colorbar(orientation='vertical', shrink=0.8, label='Percentage of Water Observations');

    return

# %%
# 1-year 24 LS-5 tiles summary

water_sum_file='/g/data/u46/users/fxz547/wofs2/summaries/water_summary_15_-40.nc'

# %%
show_water_summary(water_sum_file)

# %%
#7-year LS-5 tiles summary
watersummary ="/g/data/u46/users/fxz547/wofs2/extents_unification1/summaries/water_summary_15_-40.nc"

show_water_summary(watersummary)
