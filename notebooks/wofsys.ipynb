# %%
# WOfS-v2 System demo

# %% [markdown]
# ##  Setting up environment: python modules etc

# %%
##  Setting up environment: python modules etc

# make my current source code python modules available in this notebook
import sys

paths=sys.path
#paths.append('/g/data1/u46/fxz547/Githubz/agdc-v2')
#paths.insert(0,'/g/data1/u46/fxz547/Githubz/agdc-v2')  #prepend a path

paths.append('/g/data1/u46/fxz547/Githubz/wofs')

# %%
from IPython.display import display
from pprint import pprint
from __future__ import print_function

import os
import glob
import numpy as np
import math
from pathlib import Path

from netCDF4 import Dataset, num2date, date2num
from collections import defaultdict
import xarray as xr
import xarray.ufuncs

import datacube
from datacube.api import GridWorkflow
from datacube.storage import  masking
from datacube.storage.storage import write_dataset_to_netcdf
#from datacube.index import index_connect
#from datacube.config import LocalConfig
#from datacube.api._conversion import to_datetime
#new updated version: from datacube.api import make_mask, describe_flags

from wofs.workflow.agdc_dao import AgdcDao
import wofs.workflow.make_water_tiles as mkwater

# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10 # increase plot size a bit...
rcParams['axes.formatter.useoffset'] = False  # disable scalar formatter / offset in axes labels

# %% [markdown]
# ## Classify NBAR tiles

# %%
cellindex=(15,-40)

day1='2011-01-01'

day2='2011-12-31'

qdict = {'platform': ['LANDSAT_5'], 'time': (day1, day2)}

print (qdict)

dcdao = AgdcDao()

nbar_pq_data = dcdao.get_multi_nbarpq_tiledata(cellindex, qdict, maxtiles=50)  # maxtiles=100 for a year
#To be more specific, able to retrieve using eg, ((15, -40), numpy.datetime64('1992-09-16T09:12:23.500000000+1000'))

# todo: get DSM data for this cell
#dsm_data = dcdao.get_dsm_data(cellindex, {})

print("Number of (nbar,pqa) tile-pairs:", len(nbar_pq_data))

# Now ready to apply classification algorithm to the data tiles retrieved.

icounter = 0

for (celltime_key, nbar_tile, pq_tile) in nbar_pq_data:
    print (celltime_key)
    cellindex_tup = celltime_key[0]
    acq_dt = celltime_key[1]
    dtstamp = str(acq_dt)[:19].replace(':', '-')
    platform = 'LS5'  # can get from the nbar tile data

    water_classified_img = mkwater.produce_water_tile(nbar_tile, pq_tile) #, dsm_data[cellindex_tup])

    path2_waterfile = mkwater.define_water_fname(platform, cellindex_tup, dtstamp, nbar_tile)

    write_dataset_to_netcdf(water_classified_img,
                            global_attributes={},
                            variable_params={'waterextent': {'zlib': True}},
                            filename=Path(path2_waterfile))

    icounter += 1
# Out:
# {'platform': ['LANDSAT_5'], 'time': ('2011-01-01', '2011-12-31')}
# Number of (nbar,pqa) tile-pairs: 30
# ((15, -40), numpy.datetime64('2011-01-07T23:40:00.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6168790))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 20586, 8173901, 59927, 244318, 6168790, 1332478)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=33.396235124999997, variance=1002.5722190114734, skewness=-0.029952297932397173, kurtosis=-1.9113075121292349)
# ('DateTime of satellite observation: ', '2011-01-07T23-40-00')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-07T23-40-00.nc
# ((15, -40), numpy.datetime64('2011-01-07T23:40:24.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7274064))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 647, 7816170, 79873, 60687, 7274064, 768559)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=31.891816875, variance=990.09579904245015, skewness=0.03673213761516412, kurtosis=-1.9907056452119258)
# ('DateTime of satellite observation: ', '2011-01-07T23-40-24')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-07T23-40-24.nc
# ((15, -40), numpy.datetime64('2011-01-14T23:46:35.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(13305828))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 6682, 174308, 108813, 18154, 13305828, 2386215)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.8021974999999999, variance=56.017488422086764, skewness=8.697804167882818, kurtosis=84.51625298785734)
# ('DateTime of satellite observation: ', '2011-01-14T23-46-35')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-14T23-46-35.nc
# ((15, -40), numpy.datetime64('2011-01-30T23:46:12.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7845515))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 97429, 0, 0, 65966, 7845515, 7991090)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.2780224375, variance=98.640797001797225, skewness=12.647433753517332, kurtosis=158.38505247462243)
# ('DateTime of satellite observation: ', '2011-01-30T23-46-12')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-30T23-46-12.nc
# ((15, -40), numpy.datetime64('2011-01-30T23:46:36.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(13320282))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 5375, 0, 0, 18159, 13320282, 2656184)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=0.87778750000000005, variance=5.5705468280029242, skewness=52.48164177940334, kurtosis=2824.151949463035)
# ('DateTime of satellite observation: ', '2011-01-30T23-46-36')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-30T23-46-36.nc
# ((15, -40), numpy.datetime64('2011-02-24T23:40:02.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6264989))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 29818, 9135908, 5535, 245039, 6264989, 318711)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=37.2154376875, variance=985.14440086182822, skewness=-0.25639192044430875, kurtosis=-1.8090860522550685)
# ('DateTime of satellite observation: ', '2011-02-24T23-40-02')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-02-24T23-40-02.nc
# ((15, -40), numpy.datetime64('2011-02-24T23:40:27.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7359741))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 0, 8571638, 0, 60628, 7359741, 7993)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 64), mean=34.7541143125, variance=986.96606885157416, skewness=-0.14328863089410968, kurtosis=-1.9794514018880789)
# ('DateTime of satellite observation: ', '2011-02-24T23-40-27')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-02-24T23-40-27.nc
# ((15, -40), numpy.datetime64('2011-03-03T23:46:12.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7862625))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 104839, 0, 0, 65997, 7862625, 7966539)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.3383756874999999, variance=106.0718064610967, skewness=12.187050803428024, kurtosis=146.89378867507676)
# ('DateTime of satellite observation: ', '2011-03-03T23-46-12')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-03T23-46-12.nc
# ((15, -40), numpy.datetime64('2011-03-03T23:46:36.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(13307260))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 6311, 0, 0, 18125, 13307260, 2668304)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=0.88445737499999999, variance=6.5164345590852681, skewness=48.696620444553844, kurtosis=2422.231701512797)
# ('DateTime of satellite observation: ', '2011-03-03T23-46-36')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-03T23-46-36.nc
# ((15, -40), numpy.datetime64('2011-03-12T23:39:59.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6249954))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 191276, 0, 0, 248482, 6249954, 9310288)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.9518903750000001, variance=192.50950262082603, skewness=8.96162313817571, kurtosis=78.42969683916654)
# ('DateTime of satellite observation: ', '2011-03-12T23-39-59')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-12T23-39-59.nc
# ((15, -40), numpy.datetime64('2011-03-12T23:40:23.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7265115))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 34067, 589733, 268139, 64684, 7265115, 7778262)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=3.6299011874999998, variance=190.31122195093749, skewness=4.782798199667783, kurtosis=24.885414282363044)
# ('DateTime of satellite observation: ', '2011-03-12T23-40-23')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-12T23-40-23.nc
# ((15, -40), numpy.datetime64('2011-03-19T23:46:06.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7704078))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 31210, 4825842, 160451, 67429, 7704078, 3210990)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=20.3638835, variance=863.45412088930141, skewness=0.878597305670265, kurtosis=-1.044081822133271)
# ('DateTime of satellite observation: ', '2011-03-19T23-46-06')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-19T23-46-06.nc
# ((15, -40), numpy.datetime64('2011-03-19T23:46:30.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(13269687))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 5318, 2630526, 3873, 18410, 13269687, 72186)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=11.4040506875, variance=549.88978022254037, skewness=1.8230897497878762, kurtosis=1.3965456676315382)
# ('DateTime of satellite observation: ', '2011-03-19T23-46-30')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-19T23-46-30.nc
# ((15, -40), numpy.datetime64('2011-03-28T23:39:53.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6315073))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 130821, 3769953, 24732, 253224, 6315073, 5506197)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=16.602189062499999, variance=825.47688798782667, skewness=1.4030005599595912, kurtosis=0.6668497683043952)
# ('DateTime of satellite observation: ', '2011-03-28T23-39-53')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-28T23-39-53.nc
# ((15, -40), numpy.datetime64('2011-03-28T23:40:17.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7308213))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 24773, 764647, 295767, 69902, 7308213, 7536698)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=4.3138070624999996, variance=221.91159330949978, skewness=4.062352243835112, kurtosis=16.89959059983049)
# ('DateTime of satellite observation: ', '2011-03-28T23-40-17')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-28T23-40-17.nc
# ((15, -40), numpy.datetime64('2011-04-04T23:46:04.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7779124))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 103932, 793304, 165226, 67214, 7779124, 7091200)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=4.8297210000000002, variance=297.26346839112, skewness=4.397708859675027, kurtosis=20.864243798873588)
# ('DateTime of satellite observation: ', '2011-04-04T23-46-04')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-04-04T23-46-04.nc
# ((15, -40), numpy.datetime64('2011-04-04T23:46:28.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(13257657))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 6265, 100972, 101080, 18341, 13257657, 2515685)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.4870641874999999, variance=37.35514324945143, skewness=11.008717791726378, kurtosis=141.87562994935777)
# ('DateTime of satellite observation: ', '2011-04-04T23-46-28')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-04-04T23-46-28.nc
# ((15, -40), numpy.datetime64('2011-04-13T23:39:49.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6322856))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 141952, 2406724, 861316, 252980, 6322856, 6014172)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=12.911944999999999, variance=650.3445564635083, skewness=1.9570647317575725, kurtosis=3.163690955840341)
# ('DateTime of satellite observation: ', '2011-04-13T23-39-49')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-04-13T23-39-49.nc
# ((15, -40), numpy.datetime64('2011-08-26T23:44:59.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7614973))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 100170, 14425, 1812, 68395, 7614973, 8200225)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.3471691875, variance=105.06102430906472, skewness=12.0191097704273, kurtosis=144.21441187181262)
# ('DateTime of satellite observation: ', '2011-08-26T23-44-59')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-08-26T23-44-59.nc
# ((15, -40), numpy.datetime64('2011-08-26T23:45:23.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(13232750))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 11001, 0, 0, 18685, 13232750, 2737564)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=0.9173905, variance=11.255137498955822, skewness=37.36838505186056, kurtosis=1412.648456864894)
# ('DateTime of satellite observation: ', '2011-08-26T23-45-23')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-08-26T23-45-23.nc
# ((15, -40), numpy.datetime64('2011-09-11T23:44:48.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7639508))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 108836, 30600, 13893, 68416, 7639508, 8138747)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.5068952499999999, variance=118.39466335519494, skewness=11.067018081235148, kurtosis=123.37310138503138)
# ('DateTime of satellite observation: ', '2011-09-11T23-44-48')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-11T23-44-48.nc
# ((15, -40), numpy.datetime64('2011-09-11T23:45:12.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(13216600))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 59824, 8658, 5113, 18736, 13216600, 2691069)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.3518295, variance=62.806738428350897, skewness=15.54447645054023, kurtosis=243.04367689393143)
# ('DateTime of satellite observation: ', '2011-09-11T23-45-12')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-11T23-45-12.nc
# ((15, -40), numpy.datetime64('2011-09-20T23:38:29.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6231100))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 174413, 5237, 16545, 255497, 6231100, 9317208)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.870722875, variance=177.95218904696253, skewness=9.257339446384819, kurtosis=84.3007500694622)
# ('DateTime of satellite observation: ', '2011-09-20T23-38-29')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-20T23-38-29.nc
# ((15, -40), numpy.datetime64('2011-09-20T23:38:53.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7413380))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 33759, 72022, 71965, 70212, 7413380, 8338662)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.1742027500000001, variance=56.714748696564257, skewness=12.997340094325486, kurtosis=189.77559051378705)
# ('DateTime of satellite observation: ', '2011-09-20T23-38-53')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-20T23-38-53.nc
# ((15, -40), numpy.datetime64('2011-10-13T23:44:17.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7505203))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 4853, 7902707, 204, 74264, 7505203, 512769)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=32.128418187500003, variance=996.32796822712487, skewness=0.029240049228654093, kurtosis=-1.9788463849075535)
# ('DateTime of satellite observation: ', '2011-10-13T23-44-17')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-10-13T23-44-17.nc
# ((15, -40), numpy.datetime64('2011-10-13T23:44:41.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(12748410))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 937, 2460634, 10047, 20178, 12748410, 759794)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=10.669423875, variance=518.49004670620752, skewness=1.918370084613733, kurtosis=1.6975451271185813)
# ('DateTime of satellite observation: ', '2011-10-13T23-44-41')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-10-13T23-44-41.nc
# ((15, -40), numpy.datetime64('2011-11-07T23:37:44.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6497448))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 52631, 7758651, 4293, 254824, 6497448, 1432153)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=31.902181500000001, variance=1023.1042279850857, skewness=0.1112094588990249, kurtosis=-1.7857424056597146)
# ('DateTime of satellite observation: ', '2011-11-07T23-37-44')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-07T23-37-44.nc
# ((15, -40), numpy.datetime64('2011-11-07T23:38:08.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(7440599))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 9881, 6714419, 8265, 83928, 7440599, 1742908)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=27.428782437500001, variance=977.68634253918697, skewness=0.3348235303699104, kurtosis=-1.8444304771208768)
# ('DateTime of satellite observation: ', '2011-11-07T23-38-08')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-07T23-38-08.nc
# ((15, -40), numpy.datetime64('2011-11-14T23:43:42.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(6939706))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 100738, 0, 0, 75226, 6939706, 8884330)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=1.2490388750000001, variance=102.04815839174761, skewness=12.436053912259965, kurtosis=153.05168392738565)
# ('DateTime of satellite observation: ', '2011-11-14T23-43-42')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-14T23-43-42.nc
# ((15, -40), numpy.datetime64('2011-11-14T23:44:06.000000000'))
# ('no_data value=', -999)
# ('no data pixels: ', <xarray.DataArray ()>
# array(12974725))
# (1, 4000, 4000)
# (4000, 4000)
# ('Pixel Stats: ', 'water_pix,cloud_pix, cloudshadow_pix, noncontig_pix, nodata_pix,  nowater_pix')
# ('Pixel Stats: ', 7471, 0, 0, 20316, 12974725, 2997488)
# ('Total number of pixel should be 16M ', 16000000)
# DescribeResult(nobs=16000000, minmax=(0, 128), mean=0.87322781250000003, variance=7.7037769814625268, skewness=44.86001318463865, kurtosis=2051.943478658142)
# ('DateTime of satellite observation: ', '2011-11-14T23-44-06')
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-14T23-44-06.nc

# %%
# !ls  /g/data1/u46/fxz547/wofs2/extents/abc15_-40/*.nc
# Out:
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-16.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-39.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-04-04T09-10-42.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-05-06T09-10-28.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-06-07T09-10-29.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-09T09-10-50.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-22.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-07-25T09-10-46.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-17.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-10T09-10-41.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-12.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-08-26T09-10-36.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-09.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-11T09-10-33.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-01.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-09-27T09-10-25.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-09-54.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-13T09-10-18.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-09-46.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-10-29T10-10-10.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-09-47.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-11-14T10-10-11.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-09-43.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-12-16T10-10-07.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-07T23-40-00.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-07T23-40-24.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-14T23-46-35.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-30T23-46-12.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-01-30T23-46-36.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-02-24T23-40-02.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-02-24T23-40-27.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-03T23-46-12.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-03T23-46-36.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-12T23-39-59.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-12T23-40-23.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-19T23-46-06.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-19T23-46-30.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-28T23-39-53.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-03-28T23-40-17.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-04-04T23-46-04.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-04-04T23-46-28.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-04-13T23-39-49.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-08-26T23-44-59.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-08-26T23-45-23.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-11T23-44-48.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-11T23-45-12.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-20T23-38-29.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-09-20T23-38-53.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-10-13T23-44-17.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-10-13T23-44-41.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-07T23-37-44.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-07T23-38-08.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-14T23-43-42.nc
# /g/data1/u46/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_2011-11-14T23-44-06.nc

# %% [markdown]
# # Visualise Water Tiles

# %%
#ROOT_DIR="/g/data/u46/users/fxz547/wofs2/extents/abc15_-40/clfs"
ROOT_DIR="/g/data/u46/users/fxz547/wofs2/extents/abc15_-40"
ncfiles=glob.glob(ROOT_DIR+'/LS5_water*.nc')

#print(sorted(ncfiles))

# %%
def showimg(path2ncfile, band4view='waterextent'):

    f = Dataset(path2ncfile, 'r')

    # The NC data variable name?
    # band4view='waterextent'
    #bandarray = f[band4view][:, :]  #for water tiles 2D array. this will load all data into RAM.
    
    # for summary, there may be a time dimension, 3D array
    # 3D 
    bandarray = f[band4view][:, :, :]  

    fig = plt.figure()

    #im = plt.imshow(bandarray[time,:,:], cmap=plt.get_cmap('viridis'), animated=True)
    #im = plt.imshow(bandarray[:,:],  vmin=0, vmax=128) 
    #3D 
    im = plt.imshow(bandarray[0, :,:], vmin=0, vmax=128 ) #, cmap=plt.get_cmap('viridis'))
    plt.colorbar(orientation='vertical', shrink=0.8, label='Water=128, No-Water=0, No-Data=1');
    
    return

# %%
# Show a list of nc files

# Define the list of nc tiles to be displayed
path2nc=[os.path.join(ROOT_DIR, ncf) for ncf in sorted(ncfiles)]
icount=0

def show_im(icount):
    path2ncimage=path2nc[ icount]  #

    print('showing image number:',icount, path2ncimage)
    showimg(path2ncimage)

    icount=icount+1
    if (icount ==len(ncfiles)):
        icount =0
        print ("Finished, resetting iount=0")
    return icount

# %%
icount=20

# %%
# execute this cell (ctr+enter) repeatedly until all done

icount = show_im(icount)
print("Next will be ", icount)
# Out:
# showing image number: 1 /g/data/u46/users/fxz547/wofs2/extents/abc15_-40/LS5_water_15_-40_1990-03-03T10-11-39.nc
# Next will be  2

# %% [markdown]
# ##  Water-Summary amd Visualization

# %%
# %pwd
# Out:
# u'/g/data1/u46/users/fxz547/Githubz/wofs/notebooks'

# %%
run /g/data1/u46/users/fxz547/Githubz/wofs/wofs/workflow/make_watersummary.py /g/data/u46/users/fxz547/wofs2/extents/abc15_-40 nc 15_-40
# Out:
# 6271538.0
# 311677131.0
# done writing /g/data/u46/users/fxz547/wofs2/summaries/water_summary_15_-40.nc

# %%
def show_water_summary(path2ncfile):
    
    f = Dataset(path2ncfile, 'r')
    
    # for summary, there may be a time dimension, 3D array
    waterdata= 'waterobs'
    cleardata='clearobs'
    
    warray = f[waterdata][:,:, :]  # this will load all data into RAM - may use up memory, spit out error
    carray = f[cleardata][:,:, :]
   


    #im = plt.imshow(bandarray[time,:,:], cmap=plt.get_cmap('viridis'), animated=True)
    # 2D-tiles im = plt.imshow(bandarray[:,:] ) 
#     im = plt.imshow(bandarray[0,:,:] ) #, cmap=plt.get_cmap('viridis'))
#     plt.colorbar(orientation='vertical', shrink=0.8, label='Water=128, No-Water=0, No-Data=1');

#     plt.figure( figsize=(16,13) )
#     plt.subplot( 1,3,1 )
    plt.imshow(warray[0,:,:] ) #, vmin=0, vmax=100)
    plt.title("Water Observations"); plt.xlabel('easting'); plt.ylabel('northing')
    plt.colorbar(orientation='vertical', shrink=0.8, label='Water Obs Counts');

    
#     plt.subplot( 1,3,2 )
#     #plt.imshow(subs_array)   # plotting the subset data directly
#     plt.imshow(carray[0,:,:], vmin=0, vmax=100, )
#     plt.title("Clear Observations"); plt.xlabel('easting'); plt.ylabel('northing')
#     plt.colorbar(orientation='vertical', shrink=0.3, label='obs counts');


#      plt.subplot( 1,3,3 )
#      plt.imshow(subs_array)   # plotting the subset data directly
#     plt.imshow(warray[0,:,:]/carray[0,:,:]) #, vmin=0, vmax=1, )
#     plt.title("Water/Clear Observations"); plt.xlabel('Easting Grid'); plt.ylabel('Northing Grid')
#     plt.colorbar(orientation='vertical', shrink=0.8, label='Percentage of Water Observations');

    return

# %%
# 1-year 24 LS-5 watertiles summary

water_sum_file='/g/data/u46/users/fxz547/wofs2/summaries/water_summary_15_-40.nc'

# %%
show_water_summary(water_sum_file)

# %%
# 7-year LS-5 water tiles summary

watersummary ="/g/data/u46/users/fxz547/wofs2/extents_unification1/summaries/water_summary_15_-40.nc"

show_water_summary(watersummary)
